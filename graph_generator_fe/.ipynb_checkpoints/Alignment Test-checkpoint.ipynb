# %%
import graph_generator as gg
# Out:
# Welcome to eht-imaging! v 1.2.4

# %%
image1=gg.ImageData("../dataset_example/3C111_U_2014_05_08/3C111_U_2014_05_08.fits")
image2=gg.ImageData("../dataset_example/3C111_X_2014_05_08/3C111_X_2014_05_08.fits")

align_maps=image1.align(image2)
# Out:
# Loading fits image:  ../dataset_example/3C111_U_2014_05_08/3C111_U_2014_05_08.fits
# reading stokes images from top HDU -- assuming IQUV
# loading the AIPS CC table.
# force the pulse function to be the delta function.
# 1464 CC components are loaded.
# added 1464 CC delta components.
# converting Jy/Beam --> Jy/pixel
# the computed normalizer will not be applied since we are loading the AIPS CC table
# Loading fits image:  ../dataset_example/3C111_X_2014_05_08/3C111_X_2014_05_08.fits
# reading stokes images from top HDU -- assuming IQUV
# loading the AIPS CC table.
# force the pulse function to be the delta function.
# 1555 CC components are loaded.
# added 1555 CC delta components.
# 18 CC delta components are outside of the FoV and ignored.
# converting Jy/Beam --> Jy/pixel
# the computed normalizer will not be applied since we are loading the AIPS CC table
# RMS noise map 1: 0.00013 Jy/beam
# RMS noise map 2: 0.00013 Jy/beam
#  Will use max beam.
# ...

# %%
align_maps.plot_spix()
# Out:
# Spectral index max(alpha)=14.581539821241492 - min(alpha)=-14.631435386422584
# Cutoff -3<alpha<5
# Save spixmap to /home/flep98/VCAT/graph_generator_fe/plots/spectral_index_between_15_8.pdf

# %%
align_maps.plot_shifted_maps()
# Out:
# Save masked map plot to /home/flep98/VCAT/graph_generator_fe/plots/8GHz_convolved_with_15GHz.pdf
# Save shifted map plot to /home/flep98/VCAT/graph_generator_fe/plots/shifted_maps_15GHz_8GHz.pdf
